# %% [markdown]
# #### Water-mass Methods Package
# ##### Minimum Transport Method (MTM) Tutorial by Taimoor Sohail
#
# This tutorial script walks the user through the functionality of the MTM Code within the WM_Methods package

# %%
# Import the MTM function from the WM_Methods package
from WM_Methods import MTM
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Defining 'tracers' and 'volumes'

# %%
## Here, we create data that forms the basis of the TS bins that are fed into the optimiser
## In this tutorial, we choose the simplest example, a regular TS grid with a sinusoidal distribution weight that changes. 

# Number of watermasses

no_WMs = 20
## Note that the problem scales as no_WMs**4

## At time t1:
S1 = np.repeat(np.linspace(32,40,no_WMs)[:,np.newaxis], no_WMs,axis=-1)
T1 = np.repeat(np.linspace(-3,35,no_WMs)[np.newaxis,:], no_WMs,axis=0)
V1 = np.repeat((np.cos(np.linspace(np.pi*1.5,2.5*np.pi,no_WMs))**2)[:,np.newaxis], no_WMs,axis=-1)*\
    np.repeat((np.cos(np.linspace(np.pi*1.5,2.5*np.pi,no_WMs))**2)[np.newaxis,:], no_WMs,axis=0)

## At time t2:
## Note that the tracers X2 below do not have to stay the same - we only do this for the sake of this simple example
S2 = S1
T2 = T1
## We translate the volumes to some arbitrary location in TS space in our time t2
V2 = np.repeat((np.cos(np.linspace(np.pi*1.5,2.5*np.pi,no_WMs)-1)**2)[:,np.newaxis], no_WMs,axis=-1)*\
    np.repeat((np.cos(np.linspace(np.pi*1.5,2.5*np.pi,no_WMs)-1)**2)[np.newaxis,:], no_WMs,axis=0)

## Note that for the optimiser to work, the total initial V1 must be equal to the total final V2
# Thus, we scale the amplitude of V2 so it meets this criterion. 

V2 = V2*(V1.sum()/V2.sum())

### WE CAN ALSO TEST A PURE MIXING CASE (uncomment to try):
# V2 = np.zeros_like(V1)
# V2[(np.unravel_index(V1.argmax(), V1.shape))] = V1.sum()

### OR TEST A CASE WHERE V2 is homogeneous (uncomment to try):
# V2 = np.ones_like(V1)*(V1.sum()/V1.flatten().size)

## Check total volumes are the same 
print(V1.sum(), '=', V2.sum())

# In the real ocean, total change in volume is negligible, so V1.sum() will be approximately equal to V2.sum()
# If this is NOT the case, the optimiser will break 

## We plot the intial and final TS and volume distributions

fig, axs = plt.subplots(1,2, figsize=(10,5), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .2, wspace=0.2)
axs = axs.ravel() 

axs[0].contourf(S1, T1, V1, 500,cmap=plt.cm.viridis, vmin=0, vmax=1)
axs[0].set_title('Watermass Distribution at time t1')

axs[1].contourf(S2, T2, V2, 500,cmap=plt.cm.viridis, vmin=0, vmax=1)
axs[1].set_title('Watermass Distribution at time t2')

cax = fig.add_axes([0.925, 0.125, 0.02, 0.75])

m = plt.cm.ScalarMappable(cmap='viridis')
m.set_clim(0, 1)
cbar = fig.colorbar(m, cax=cax, orientation='vertical')
cbar.set_label('Volume') 

plt.show()
# Out:
# 90.25 = 90.25000000000001

# %%
## Here, we create the tracers and volumes matrices, which will be fed into the MTM function

volumes = np.stack((V1.flatten(), V2.flatten()), axis=0) # Shape: [2 x N]

salinities = np.stack((S1.flatten(), S2.flatten()), axis=0)
temps = np.stack((T1.flatten(), T2.flatten()), axis=0)
## Add any further tracers at this line
generic_tracer = np.ones_like(temps)

tracers = np.stack((salinities, temps, generic_tracer),axis=1) # Shape: [2 x M x N], where M = 2 for just T and S, and M>2 for T,S+other tracers

# %% [markdown]
# ### Defining 'constraints'

# %%
## The constraints matrix, which is between 0 and 1, (0 = disconnected; 1 = fully connected) defines the connectivity from one N watermass to another N watermass. 
# Here, we define all watermasses as fully connected, but this could be tweaked to be any number between 0 and 1. 

constraints = np.ones((V1.flatten().size,V2.flatten().size)) # Shape: [N x N] matrix

# %% [markdown]
# ### Defining 'weights'

# %%
## The weights matrix defines any weighting (e.g. by surface area) to apply to the transport matrix
## Here, we define surface area for each water mass as 1 everywhere (i.e., it doesn't have a weight)

A1 = np.repeat((np.cos(np.linspace(np.pi*1.5,2.5*np.pi,no_WMs))**2)[:,np.newaxis], no_WMs,axis=-1)*\
    np.repeat((np.cos(np.linspace(np.pi*1.5,2.5*np.pi,no_WMs))**2)[np.newaxis,:], no_WMs,axis=0)
A2 = A1/A1

## A scaling to weight T and S changes equivalently:
alph = 1.7657*10**-4
bet = 7.5544*10**-4
ST_scale = (bet/alph)

## We create a weight matrix of ones
# Note that the code is very sensitive to the weights we input, and may break (TO BE DEVELOPED)
weights = np.stack((A2.flatten(),A2.flatten(), A2.flatten()), axis=0) # Shape: An [M x N] matrix

# %%
### OVERRIDING PARAMS IF WE WANT TO ASSESS SIMPLE 2-4 WM cases ###
## Comment this out to run the usual tutorial case above ##
#T1 = np.array([1,3,2,2])
#T2 = np.array([2,2,2,2])
#S1 = np.array([1,1,0,2])
#S2 = np.array([1,1,1,1])
#V1 = np.array([1,1,1,1])
#V2 = np.array([4,0,0,0])
#A1 = np.array([1,1,1,1])
#A2 = np.array([4,3,2,1])

volumes = np.stack((V1.flatten(), V2.flatten()), axis=0) # Shape: [2 x N]

salinities = np.stack((S1.flatten(), S2.flatten()), axis=0)
temps = np.stack((T1.flatten(), T2.flatten()), axis=0)
## Add any further tracers at this line
# generic_tracer = np.ones_like(temps)

tracers = np.stack((salinities, temps),axis=1) # Shape: [2 x M x N], where M = 2 for just T and S, and M>2 for T,S+other tracers
constraints = np.ones((V1.flatten().size,V2.flatten().size))
weights = np.stack((A2.flatten(),A2.flatten()), axis=0)

# %% [markdown]
# ### Running the optimiser

# %%
## We run the optimiser to get the transports between water masses and the T,S mixed and T,S adjustment

result = MTM.optimise(tracers, volumes, constraints, weights)

g_ij = result['g_ij'] ## An [N x N] matrix of transports between WMs
Mixing = result['Mixing'] ## An [M x N] matrix of dtracer mixing for each WM
Adjustment = result['Adjustment'] ## An [M x N] matrix of dtracer adjustment for each WM
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) Jul 15 05:36:39 PM: Your problem has 160000 variables, 2 constraints, and 0 parameters.
# (CVXPY) Jul 15 05:36:39 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 15 05:36:39 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 15 05:36:39 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 15 05:36:39 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Jul 15 05:36:39 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Jul 15 05:36:39 PM: Applying reduction Dcp2Cone
# (CVXPY) Jul 15 05:36:39 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 15 05:36:39 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jul 15 05:36:43 PM: Applying reduction MOSEK
# (CVXPY) Jul 15 05:36:43 PM: Finished problem compilation (took 3.564e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 15 05:36:43 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Jul 15 05:36:43 PM: Problem
# (CVXPY) Jul 15 05:36:43 PM:   Name                   :
# (CVXPY) Jul 15 05:36:43 PM:   Objective sense        : max
# (CVXPY) Jul 15 05:36:43 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Jul 15 05:36:43 PM:   Constraints            : 160001
# (CVXPY) Jul 15 05:36:43 PM:   Cones                  : 1
# (CVXPY) Jul 15 05:36:43 PM:   Scalar variables       : 161602
# (CVXPY) Jul 15 05:36:43 PM:   Matrix variables       : 0
# (CVXPY) Jul 15 05:36:43 PM:   Integer variables      : 0
# (CVXPY) Jul 15 05:36:43 PM:
# (CVXPY) Jul 15 05:36:43 PM: Optimizer started.
# (CVXPY) Jul 15 05:36:44 PM: Presolve started.
# (CVXPY) Jul 15 05:36:44 PM: Linear dependency checker started.
# (CVXPY) Jul 15 05:36:44 PM: Linear dependency checker terminated.
# (CVXPY) Jul 15 05:36:44 PM: Eliminator started.
# (CVXPY) Jul 15 05:36:44 PM: Freed constraints in eliminator : 0
# (CVXPY) Jul 15 05:36:44 PM: Eliminator terminated.
# (CVXPY) Jul 15 05:36:44 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Jul 15 05:36:44 PM: Lin. dep.  - tries                  : 1                 time                   : 0.05
# (CVXPY) Jul 15 05:36:44 PM: Lin. dep.  - number                 : 1
# (CVXPY) Jul 15 05:36:44 PM: Presolve terminated. Time: 0.42
# (CVXPY) Jul 15 05:36:44 PM: Problem
# (CVXPY) Jul 15 05:36:44 PM:   Name                   :
# (CVXPY) Jul 15 05:36:44 PM:   Objective sense        : max
# (CVXPY) Jul 15 05:36:44 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Jul 15 05:36:44 PM:   Constraints            : 160001
# (CVXPY) Jul 15 05:36:44 PM:   Cones                  : 1
# (CVXPY) Jul 15 05:36:44 PM:   Scalar variables       : 161602
# (CVXPY) Jul 15 05:36:44 PM:   Matrix variables       : 0
# (CVXPY) Jul 15 05:36:44 PM:   Integer variables      : 0
# (CVXPY) Jul 15 05:36:44 PM:
# (CVXPY) Jul 15 05:36:44 PM: Optimizer  - threads                : 4
# (CVXPY) Jul 15 05:36:44 PM: Optimizer  - solved problem         : the dual
# (CVXPY) Jul 15 05:36:44 PM: Optimizer  - Constraints            : 1521
# (CVXPY) Jul 15 05:36:44 PM: Optimizer  - Cones                  : 1
# (CVXPY) Jul 15 05:36:44 PM: Optimizer  - Scalar variables       : 130077            conic                  : 801
# (CVXPY) Jul 15 05:36:44 PM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Jul 15 05:36:44 PM: Factor     - setup time             : 0.17              dense det. time        : 0.00
# (CVXPY) Jul 15 05:36:44 PM: Factor     - ML order time          : 0.01              GP order time          : 0.00
# (CVXPY) Jul 15 05:36:44 PM: Factor     - nonzeros before factor : 3.91e+05          after factor           : 4.44e+05
# (CVXPY) Jul 15 05:36:44 PM: Factor     - dense dim.             : 2                 flops                  : 1.42e+08
# (CVXPY) Jul 15 05:36:44 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Jul 15 05:36:44 PM: 0   0.0e+00  1.0e+00  2.0e+00  0.00e+00   -1.000000000e+00  0.000000000e+00   1.0e+00  0.80
# (CVXPY) Jul 15 05:36:44 PM: 1   4.1e-14  3.3e-01  1.1e+00  -9.16e-01  1.155736570e+01   1.079497532e+01   3.3e-01  1.00
# (CVXPY) Jul 15 05:36:46 PM: 21  4.4e-12  1.7e-07  9.2e-09  1.04e+00   2.615825159e+03   2.615824445e+03   1.7e-07  3.05
# (CVXPY) Jul 15 05:36:47 PM: 22  9.6e-12  1.3e-07  6.0e-09  1.03e+00   2.618511222e+03   2.618510686e+03   1.3e-07  3.19
# (CVXPY) Jul 15 05:36:47 PM: 23  1.2e-11  5.3e-08  1.6e-09  1.02e+00   2.623044704e+03   2.623044482e+03   5.3e-08  3.33
# (CVXPY) Jul 15 05:36:47 PM: 24  2.5e-11  3.5e-08  8.6e-10  1.02e+00   2.623992806e+03   2.623992661e+03   3.5e-08  3.45
# (CVXPY) Jul 15 05:36:47 PM: 25  1.0e-10  1.4e-08  2.2e-10  1.01e+00   2.625035494e+03   2.625035436e+03   1.4e-08  3.59
# (CVXPY) Jul 15 05:36:47 PM: 26  1.2e-06  8.3e-09  9.9e-11  1.01e+00   2.625290782e+03   2.625290748e+03   8.3e-09  3.64
# (CVXPY) Jul 15 05:36:47 PM: 27  3.5e-06  3.0e-09  2.1e-11  1.02e+00   2.625520165e+03   2.625520153e+03   3.0e-09  3.70
# (CVXPY) Jul 15 05:36:47 PM: 28  9.1e-07  7.8e-10  2.6e-12  1.02e+00   2.625609309e+03   2.625609306e+03   7.8e-10  3.83
# (CVXPY) Jul 15 05:36:47 PM: 29  5.3e-05  2.6e-10  5.6e-13  1.01e+00   2.625627674e+03   2.625627673e+03   2.6e-10  3.88
# (CVXPY) Jul 15 05:36:47 PM: Optimizer terminated. Time: 3.95
# (CVXPY) Jul 15 05:36:47 PM:
# (CVXPY) Jul 15 05:36:47 PM:
# (CVXPY) Jul 15 05:36:47 PM: Interior-point solution summary
# (CVXPY) Jul 15 05:36:47 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Jul 15 05:36:47 PM:   Solution status : OPTIMAL
# (CVXPY) Jul 15 05:36:47 PM:   Primal.  obj: 2.6256276738e+03    nrm: 1e+03    Viol.  con: 6e-14    var: 3e-14    cones: 0e+00
# (CVXPY) Jul 15 05:36:47 PM:   Dual.    obj: 2.6256276735e+03    nrm: 3e+03    Viol.  con: 0e+00    var: 1e-06    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 15 05:36:48 PM: Problem status: optimal
# (CVXPY) Jul 15 05:36:48 PM: Optimal value: 2.626e+03
# (CVXPY) Jul 15 05:36:48 PM: Compilation took 3.564e+00 seconds
# (CVXPY) Jul 15 05:36:48 PM: Solver (including time spent in interface) took 4.462e+00 seconds
# Optimal value: 2625.627448335566
# Variable var1: value [-0. -0. -0. ... -0. -0. -0.]

# %%
## Plot the transport g_ij from WM initial to WM final

plt.pcolormesh(g_ij,vmin=0,vmax=0.005)
cbar = plt.colorbar()
cbar.set_label('Transport between WMs')
plt.xlabel('Final WM')
plt.ylabel('Initial WM')
plt.show()

# %%
## Break down the Mixing and Adjustment matrices into their constituent tracers
dT_mixing = Mixing[1,:]
dS_mixing = Mixing[0,:]
dS_adj = Adjustment[0,:]
dT_adj = Adjustment[1,:]
## Uncomment if M>2
# dtracer_mixing = Mixing[2,:]
# dtracer_adj = Adjustment[2,:]

# %%
print(dS_mixing)
print(dT_mixing)
print(dS_adj)
print(dT_adj)
# Out:
#  -7.31890671e+00 -7.99972338e+00 -7.87355825e+00 -5.99978873e+00
#  -3.99984592e+00 -2.00017582e+00 -9.16457200e-02  1.99934773e+00
#   3.71345756e+00  4.00024056e+00  5.99998016e+00  6.66767417e+00
#   7.89050316e+00  7.99983137e+00  8.20971493e+00  7.92180522e+00
#   7.90113342e+00  8.32803612e+00  9.30468678e+00  1.10964316e+01]

# %% [markdown]
# ### Plotting tracer mixing and adjustment

# %%
## Vector Plot
# Here, we plot the vectors of mixing and adjustment from the initial watermass outwards

for i in range(V1.flatten().size):
        plt.scatter(tracers[0,0,i],tracers[0,1,i],\
                s=50,\
                marker = 'x', label = 't1', color='grey', zorder=100)
        plt.scatter(tracers[1,0,i],tracers[1,1,i],\
                s=5,\
                marker = 's', label = 't2', color='black', zorder=100)
#        plt.annotate('', xy=(tracers[0,0,i], tracers[0,1,i]), xytext=(tracers[0,0,i]+dS_mixing[i], tracers[0,1,i]+dT_mixing[i]),
#        arrowprops=dict(arrowstyle="<-", color='blue'))
        plt.annotate('', xy=(tracers[0,0,i]+dS_mixing[i], tracers[0,1,i]+dT_mixing[i]), 
                        xytext=(tracers[0,0,i]+dS_mixing[i]+dS_adj[i], tracers[0,1,i]+dT_mixing[i]+dT_adj[i]),
        arrowprops=dict(arrowstyle="<-", color='red'))

        plt.xlim(32,40)
        plt.ylim(-10,35)
plt.show()

# %%
## Visualise T and S mixing and adjustment as a colourmap on the initial watermass locations

fig, axs = plt.subplots(3,2, figsize=(5,7.5), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .3, wspace=0.2)
axs = axs.ravel() 

minv, maxv = -10,10
cmap = plt.cm.bwr
norm = plt.Normalize(minv, maxv)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

axs[0].scatter(tracers[0,0,:], tracers[0,1,:], 10, color=cmap(norm(dS_adj[:])), zorder=100)
axs[0].set_title('Salinity Adjustment')

axs[1].scatter(tracers[0,0,:], tracers[0,1,:], 10, color=cmap(norm(dT_adj[:])), zorder=100)
axs[1].set_title('Temperature Adjustment')

axs[2].scatter(tracers[0,0,:], tracers[0,1,:], 10, color=cmap(norm(dS_mixing[:])), zorder=100)
axs[2].set_title('Salinity Mixing')

axs[3].scatter(tracers[0,0,:], tracers[0,1,:], 10, color=cmap(norm(dT_mixing[:])), zorder=100)
axs[3].set_title('Temperature Mixing')

axs[4].scatter(tracers[0,0,:], tracers[0,1,:], 10, color=cmap(norm(dS_mixing+dS_adj)), zorder=100)
axs[4].set_title('Total Salinity Change')

axs[5].scatter(tracers[0,0,:], tracers[0,1,:], 10, color=cmap(norm(dT_mixing+dT_adj)), zorder=100)
axs[5].set_title('Total Temperature Change')

plt.show()

# %%
## Visualise other tracer mixing and adjustment as a colourmap on the initial watermass locations

fig, axs = plt.subplots(1,3, figsize=(15,5), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .3, wspace=0.2)
axs = axs.ravel() 


minv, maxv = -1,1
cmap = plt.cm.bwr
norm = plt.Normalize(minv, maxv)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

axs[0].scatter(tracers[0,0,:], tracers[0,1,:], 10, color=cmap(norm(dtracer_adj[:])), zorder=100)
axs[0].set_title('Tracer Adjustment')

axs[1].scatter(tracers[0,0,:], tracers[0,1,:], 10, color=cmap(norm(dtracer_mixing[:])), zorder=100)
axs[1].set_title('Tracer Mixing')

axs[2].scatter(tracers[0,0,:], tracers[0,1,:], 10, color=cmap(norm(dtracer_mixing+dtracer_adj)), zorder=100)
axs[2].set_title('Tracer Total')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c94eb830495e> in <module>
#      12 sm.set_array([])
#      13
# ---> 14 axs[0].scatter(tracers[0,0,:], tracers[0,1,:], 10, color=cmap(norm(dtracer_adj[:])), zorder=100)
#      15 axs[0].set_title('Tracer Adjustment')
#      16
#
# NameError: name 'dtracer_adj' is not defined

# %%
from platform import python_version
print(python_version())

# %%
print(g_ij.shape)
print(tracers.shape)
# Out:
# (400, 400)
# (2, 2, 400)
